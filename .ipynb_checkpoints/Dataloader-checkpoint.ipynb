# %% [markdown]
# # Download Data

# %%
#numpy
import numpy as np

#PyTorch
import torchvision.utils as vutils


#Plotting
import matplotlib.pyplot as plt

#Downloading DTU Data
import Downloader

#Learned Manifolds
import ManLearn

# %%
base_url = 'https://orbit.dtu.dk'
folder_name = '../../../../Data/DTU_orbit/orbit/'
remove_folder = '../../../../Data/DTU_orbit/remove_images/'

# %% [markdown]
# ## Download Raw Data

# %%
Downloader.iterator(folder_name, base_url)
# Out:
# Iteration 1/154
# -Downloaded 50/50
# Iteration 2/154
# -Downloaded 50/50
# Iteration 3/154
# -Downloaded 50/50
# Iteration 4/154
# -Downloaded 50/50
# Iteration 5/154
# -Downloaded 50/50
# Iteration 6/154
# -Downloaded 50/50
# Iteration 7/154
# -Downloaded 50/50
# Iteration 8/154
# -Downloaded 50/50
# Iteration 9/154
# -Downloaded 50/50
# Iteration 10/154
# -Downloaded 50/50
# Iteration 11/154
# -Downloaded 50/50
# Iteration 12/154
# -Downloaded 50/50
# Iteration 13/154
# -Downloaded 50/50
# Iteration 14/154
# -Downloaded 50/50
# Iteration 15/154
# -Downloaded 50/50
# Iteration 16/154
# -Downloaded 50/50
# Iteration 17/154
# -Downloaded 50/50
# Iteration 18/154
# -Downloaded 50/50
# Iteration 19/154
# -Downloaded 50/50
# Iteration 20/154
# -Downloaded 50/50
# Iteration 21/154
# -Downloaded 50/50
# Iteration 22/154
# -Downloaded 50/50
# Iteration 23/154
# -Downloaded 50/50
# Iteration 24/154
# -Downloaded 50/50
# Iteration 25/154
# -Downloaded 50/50
# Iteration 26/154
# -Downloaded 50/50
# Iteration 27/154
# -Downloaded 50/50
# Iteration 28/154
# -Downloaded 50/50
# Iteration 29/154
# -Downloaded 50/50
# Iteration 30/154
# -Downloaded 50/50
# Iteration 31/154
# -Downloaded 50/50
# Iteration 32/154
# -Downloaded 50/50
# Iteration 33/154
# -Downloaded 50/50
# Iteration 34/154
# -Downloaded 50/50
# Iteration 35/154
# -Downloaded 50/50
# Iteration 36/154
# -Downloaded 50/50
# Iteration 37/154
# -Downloaded 50/50
# Iteration 38/154
# -Downloaded 50/50
# Iteration 39/154
# -Downloaded 50/50
# Iteration 40/154
# -Downloaded 50/50
# Iteration 41/154
# -Downloaded 50/50
# Iteration 42/154
# -Downloaded 50/50
# Iteration 43/154
# -Downloaded 50/50
# Iteration 44/154
# -Downloaded 50/50
# Iteration 45/154
# -Downloaded 50/50
# Iteration 46/154
# -Downloaded 50/50
# Iteration 47/154
# -Downloaded 50/50
# Iteration 48/154
# -Downloaded 50/50
# Iteration 49/154
# -Downloaded 50/50
# Iteration 50/154
# -Downloaded 50/50
# Iteration 51/154
# -Downloaded 50/50
# Iteration 52/154
# -Downloaded 50/50
# Iteration 53/154
# -Downloaded 50/50
# Iteration 54/154
# -Downloaded 50/50
# Iteration 55/154
# -Downloaded 50/50
# Iteration 56/154
# -Downloaded 50/50
# Iteration 57/154
# -Downloaded 50/50
# Iteration 58/154
# -Downloaded 50/50
# Iteration 59/154
# -Downloaded 50/50
# Iteration 60/154
# -Downloaded 50/50
# Iteration 61/154
# -Downloaded 50/50
# Iteration 62/154
# -Downloaded 50/50
# Iteration 63/154
# -Downloaded 50/50
# Iteration 64/154
# -Downloaded 50/50
# Iteration 65/154
# -Downloaded 50/50
# Iteration 66/154
# -Downloaded 50/50
# Iteration 67/154
# -Downloaded 50/50
# Iteration 68/154
# -Downloaded 50/50
# Iteration 69/154
# -Downloaded 50/50
# Iteration 70/154
# -Downloaded 50/50
# Iteration 71/154
# -Downloaded 50/50
# Iteration 72/154
# -Downloaded 50/50
# Iteration 73/154
# -Downloaded 50/50
# Iteration 74/154
# -Downloaded 50/50
# Iteration 75/154
# -Downloaded 50/50
# Iteration 76/154
# -Downloaded 50/50
# Iteration 77/154
# -Downloaded 50/50
# Iteration 78/154
# -Downloaded 50/50
# Iteration 79/154
# -Downloaded 50/50
# Iteration 80/154
# -Downloaded 50/50
# Iteration 81/154
# -Downloaded 50/50
# Iteration 82/154
# -Downloaded 50/50
# Iteration 83/154
# -Downloaded 50/50
# Iteration 84/154
# -Downloaded 50/50
# Iteration 85/154
# -Downloaded 50/50
# Iteration 86/154
# -Downloaded 50/50
# Iteration 87/154
# -Downloaded 50/50
# Iteration 88/154
# -Downloaded 50/50
# Iteration 89/154
# -Downloaded 50/50
# Iteration 90/154
# -Downloaded 50/50
# Iteration 91/154
# -Downloaded 50/50
# Iteration 92/154
# -Downloaded 50/50
# Iteration 93/154
# -Downloaded 50/50
# Iteration 94/154
# -Downloaded 50/50
# Iteration 95/154
# -Downloaded 50/50
# Iteration 96/154
# -Downloaded 50/50
# Iteration 97/154
# -Downloaded 50/50
# Iteration 98/154
# -Downloaded 50/50
# Iteration 99/154
# -Downloaded 50/50
# Iteration 100/154
# -Downloaded 50/50
# Iteration 101/154
# -Downloaded 50/50
# Iteration 102/154
# -Downloaded 50/50
# Iteration 103/154
# -Downloaded 50/50
# Iteration 104/154
# -Downloaded 50/50
# Iteration 105/154
# -Downloaded 50/50
# Iteration 106/154
# -Downloaded 50/50
# Iteration 107/154
# -Downloaded 50/50
# Iteration 108/154
# -Downloaded 50/50
# Iteration 109/154
# -Downloaded 50/50
# Iteration 110/154
# -Downloaded 50/50
# Iteration 111/154
# -Downloaded 50/50
# Iteration 112/154
# -Downloaded 50/50
# Iteration 113/154
# -Downloaded 50/50
# Iteration 114/154
# -Downloaded 50/50
# Iteration 115/154
# -Downloaded 50/50
# Iteration 116/154
# -Downloaded 50/50
# Iteration 117/154
# -Downloaded 50/50
# Iteration 118/154
# -Downloaded 50/50
# Iteration 119/154
# -Downloaded 50/50
# Iteration 120/154
# -Downloaded 50/50
# Iteration 121/154
# -Downloaded 50/50
# Iteration 122/154
# -Downloaded 50/50
# Iteration 123/154
# -Downloaded 50/50
# Iteration 124/154
# -Downloaded 50/50
# Iteration 125/154
# -Downloaded 50/50
# Iteration 126/154
# -Downloaded 50/50
# Iteration 127/154
# -Downloaded 50/50
# Iteration 128/154
# -Downloaded 50/50
# Iteration 129/154
# -Downloaded 50/50
# Iteration 130/154
# -Downloaded 50/50
# Iteration 131/154
# -Downloaded 50/50
# Iteration 132/154
# -Downloaded 50/50
# Iteration 133/154
# -Downloaded 50/50
# Iteration 134/154
# -Downloaded 50/50
# Iteration 135/154
# -Downloaded 50/50
# Iteration 136/154
# -Downloaded 50/50
# Iteration 137/154
# -Downloaded 50/50
# Iteration 138/154
# -Downloaded 50/50
# Iteration 139/154
# -Downloaded 50/50
# Iteration 140/154
# -Downloaded 50/50
# Iteration 141/154
# -Downloaded 50/50
# Iteration 142/154
# -Downloaded 50/50
# Iteration 143/154
# -Downloaded 50/50
# Iteration 144/154
# -Downloaded 50/50
# Iteration 145/154
# -Downloaded 50/50
# Iteration 146/154
# -Downloaded 50/50
# Iteration 147/154
# -Downloaded 50/50
# Iteration 148/154
# -Downloaded 49/50
# Iteration 149/154
# -Downloaded 50/50
# Iteration 150/154
# -Downloaded 50/50
# Iteration 151/154
# -Downloaded 50/50
# Iteration 152/154
# -Downloaded 50/50
# Iteration 153/154
# -Downloaded 50/50
# Iteration 154/154
# -Downloaded 50/50
# Iteration 155/154
# -Downloaded 26/26

# %% [markdown]
# ## Clean Data

# %%
Downloader.clean_data(folder_name, remove_folder)
# Out:
# Remaining images are 6909/7724

# %% [markdown]
# ## Rename Images

# %%
Downloader.rename_data(folder_name)

# %% [markdown]
# ## Plotting Images

# %%
dataset, dataset_subset, trainloader = ManLearn.load_dtu(folder_name,
                                                        batch_size=64,
                                                        img_size=64,
                                                        frac=0.8,
                                                        workers=0)

# %%
real_batch = next(iter(trainloader))

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(np.transpose(vutils.make_grid(real_batch[0].to('cpu'), padding=2, normalize=True).cpu(), (1,2,0)))
ax.set_axis_off()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_186270/2289215412.py in <module>
#       1 fig = plt.figure(figsize=(10,10))
#       2 ax = fig.add_subplot(111)
# ----> 3 ax.imshow(np.transpose(vutils.make_grid(real_batch[0].to('cpu'), padding=2, normalize=True).cpu(), (1,2,0)))
#       4 ax.set_axis_off()
#
# NameError: name 'vutils' is not defined
